# %% [markdown]
# <a href="https://colab.research.google.com/github/jc020230/2026-1-basic-practice-Kwak-/blob/main/chapter08_image_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is a companion notebook for the book [Deep Learning with Python, Third Edition](https://www.manning.com/books/deep-learning-with-python-third-edition). For readability, it only contains runnable code blocks and section titles, and omits everything else in the book: text paragraphs, figures, and pseudocode.
#
# **If you want to be able to follow what's going on, I recommend reading the notebook side by side with your copy of the book.**
#
# The book's contents are available online at [deeplearningwithpython.io](https://deeplearningwithpython.io).

# %%
# !pip install keras keras-hub --upgrade -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 21.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 44.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# keras-nlp 0.21.1 requires keras-hub==0.21.1, but you have keras-hub 0.26.0 which is incompatible.

# %%
import os
os.environ["KERAS_BACKEND"] = "jax"

# %%
# @title
import os
from IPython.core.magic import register_cell_magic

@register_cell_magic
def backend(line, cell):
    current, required = os.environ.get("KERAS_BACKEND", ""), line.split()[-1]
    if current == required:
        get_ipython().run_cell(cell)
    else:
        print(
            f"This cell requires the {required} backend. To run it, change KERAS_BACKEND to "
            f"\"{required}\" at the top of the notebook, restart the runtime, and rerun the notebook."
        )

# %% [markdown]
# ## Image classification

# %% [markdown]
# ### Introduction to ConvNets

# %%
import keras
from keras import layers

inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(inputs)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.GlobalAveragePooling2D()(x)
outputs = layers.Dense(10, activation="softmax")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary(line_length=80)
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                      ┃ Output Shape             ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)          │ (None, 28, 28, 1)        │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                   │ (None, 26, 26, 64)       │           640 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)      │ (None, 13, 13, 64)       │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)                 │ (None, 11, 11, 128)      │        73,856 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)    │ (None, 5, 5, 128)        │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)                 │ (None, 3, 3, 256)        │       295,168 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ global_average_pooling2d          │ (None, 256)              │             0 │
# │ (GlobalAveragePooling2D)          │                          │               │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ dense (Dense)                     │ (None, 10)               │         2,570 │
# └───────────────────────────────────┴──────────────────────────┴───────────────┘
#  Total params: 372,234 (1.42 MB)
#  Trainable params: 372,234 (1.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from keras.datasets import mnist

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images.reshape((60000, 28, 28, 1))
train_images = train_images.astype("float32") / 255
test_images = test_images.reshape((10000, 28, 28, 1))
test_images = test_images.astype("float32") / 255
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)
model.fit(train_images, train_labels, epochs=5, batch_size=64)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 15s 8ms/step - accuracy: 0.9209 - loss: 0.2522
# Epoch 2/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9786 - loss: 0.0679
# Epoch 3/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9851 - loss: 0.0467
# Epoch 4/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9880 - loss: 0.0372
# Epoch 5/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9915 - loss: 0.0282

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9900 - loss: 0.0329
# Test accuracy: 0.990

# %% [markdown]
# #### The convolution operation

# %% [markdown]
# ##### Understanding border effects and padding

# %% [markdown]
# ##### Understanding convolution strides

# %% [markdown]
# #### The max-pooling operation

# %%
inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(inputs)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.GlobalAveragePooling2D()(x)
outputs = layers.Dense(10, activation="softmax")(x)
model_no_max_pool = keras.Model(inputs=inputs, outputs=outputs)

# %%
model_no_max_pool.summary(line_length=80)
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                      ┃ Output Shape             ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)        │ (None, 28, 28, 1)        │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)                 │ (None, 26, 26, 64)       │           640 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)                 │ (None, 24, 24, 128)      │        73,856 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)                 │ (None, 22, 22, 256)      │       295,168 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ global_average_pooling2d_1        │ (None, 256)              │             0 │
# │ (GlobalAveragePooling2D)          │                          │               │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ dense_1 (Dense)                   │ (None, 10)               │         2,570 │
# └───────────────────────────────────┴──────────────────────────┴───────────────┘
#  Total params: 372,234 (1.42 MB)
#  Trainable params: 372,234 (1.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Training a ConvNet from scratch on a small dataset

# %% [markdown]
# #### The relevance of deep learning for small-data problems

# %% [markdown]
# #### Downloading the data

# %%
import os

# 본인의 kaggle.json 파일 안에 있는 값을 그대로 적어주세요.
os.environ['KAGGLE_USERNAME'] = "jungchanryu"
os.environ['KAGGLE_KEY'] = "126f74ec855dc0001040b3a47ebde855"

# %%
import kagglehub

kagglehub.login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://www.kaggle.com/static/images/site-logo.png\nalt=\'Kaggle…
# Kaggle credentials set.
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.13), please consider upgrading to the latest version (1.0.0).
# Kaggle credentials successfully validated.

# %%
download_path = kagglehub.competition_download("dogs-vs-cats")
# Out:
# Downloading from https://www.kaggle.com/api/v1/competitions/data/download-all/dogs-vs-cats...
# 100%|██████████| 812M/812M [00:06<00:00, 127MB/s]
# Extracting files...

# %%
import zipfile

with zipfile.ZipFile(download_path + "/train.zip", "r") as zip_ref:
    zip_ref.extractall(".")

# %%
import os, shutil, pathlib

original_dir = pathlib.Path("train")
new_base_dir = pathlib.Path("dogs_vs_cats_small")

def make_subset(subset_name, start_index, end_index):
    for category in ("cat", "dog"):
        dir = new_base_dir / subset_name / category
        os.makedirs(dir)
        fnames = [f"{category}.{i}.jpg" for i in range(start_index, end_index)]
        for fname in fnames:
            shutil.copyfile(src=original_dir / fname, dst=dir / fname)

make_subset("train", start_index=0, end_index=1000)
make_subset("validation", start_index=1000, end_index=1500)
make_subset("test", start_index=1500, end_index=2500)

# %% [markdown]
# #### Building your model

# %%
import keras
from keras import layers

inputs = keras.Input(shape=(180, 180, 3))
x = layers.Rescaling(1.0 / 255)(inputs)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=512, kernel_size=3, activation="relu")(x)
x = layers.GlobalAveragePooling2D()(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary(line_length=80)
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                      ┃ Output Shape             ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)        │ (None, 180, 180, 3)      │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ rescaling (Rescaling)             │ (None, 180, 180, 3)      │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)                 │ (None, 178, 178, 32)     │           896 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)    │ (None, 89, 89, 32)       │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)                 │ (None, 87, 87, 64)       │        18,496 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)    │ (None, 43, 43, 64)       │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)                 │ (None, 41, 41, 128)      │        73,856 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)    │ (None, 20, 20, 128)      │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)                 │ (None, 18, 18, 256)      │       295,168 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)    │ (None, 9, 9, 256)        │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)                │ (None, 7, 7, 512)        │     1,180,160 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ global_average_pooling2d_2        │ (None, 512)              │             0 │
# │ (GlobalAveragePooling2D)          │                          │               │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ dense_2 (Dense)                   │ (None, 1)                │           513 │
# └───────────────────────────────────┴──────────────────────────┴───────────────┘
#  Total params: 1,569,089 (5.99 MB)
#  Trainable params: 1,569,089 (5.99 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    loss="binary_crossentropy",
    optimizer="adam",
    metrics=["accuracy"],
)

# %% [markdown]
# #### Data preprocessing

# %%
from keras.utils import image_dataset_from_directory

batch_size = 64
image_size = (180, 180)
train_dataset = image_dataset_from_directory(
    new_base_dir / "train", image_size=image_size, batch_size=batch_size
)
validation_dataset = image_dataset_from_directory(
    new_base_dir / "validation", image_size=image_size, batch_size=batch_size
)
test_dataset = image_dataset_from_directory(
    new_base_dir / "test", image_size=image_size, batch_size=batch_size
)
# Out:
# Found 2000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.
# Found 2000 files belonging to 2 classes.

# %% [markdown]
# ##### Understanding TensorFlow Dataset objects

# %%
import numpy as np
import tensorflow as tf

random_numbers = np.random.normal(size=(1000, 16))
dataset = tf.data.Dataset.from_tensor_slices(random_numbers)

# %%
for i, element in enumerate(dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (16,)
# (16,)
# (16,)

# %%
batched_dataset = dataset.batch(32)
for i, element in enumerate(batched_dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (32, 16)
# (32, 16)
# (32, 16)

# %%
reshaped_dataset = dataset.map(
    lambda x: tf.reshape(x, (4, 4)),
    num_parallel_calls=8)
for i, element in enumerate(reshaped_dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (4, 4)
# (4, 4)
# (4, 4)

# %% [markdown]
# ##### Fitting the model

# %%
for data_batch, labels_batch in train_dataset:
    print("data batch shape:", data_batch.shape)
    print("labels batch shape:", labels_batch.shape)
    break
# Out:
# data batch shape: (64, 180, 180, 3)
# labels batch shape: (64,)

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch.keras",
        save_best_only=True,
        monitor="val_loss",
    )
]
history = model.fit(
    train_dataset,
    epochs=50,
    validation_data=validation_dataset,
    callbacks=callbacks,
)
# Out:
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 18s 353ms/step - accuracy: 0.5025 - loss: 0.6972 - val_accuracy: 0.5670 - val_loss: 0.6914
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 113ms/step - accuracy: 0.5510 - loss: 0.6839 - val_accuracy: 0.5110 - val_loss: 0.7046
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - accuracy: 0.5770 - loss: 0.6702 - val_accuracy: 0.5740 - val_loss: 0.6707
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - accuracy: 0.6165 - loss: 0.6557 - val_accuracy: 0.6470 - val_loss: 0.6329
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - accuracy: 0.6395 - loss: 0.6359 - val_accuracy: 0.5830 - val_loss: 0.6740
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 138ms/step - accuracy: 0.6565 - loss: 0.6285 - val_accuracy: 0.6950 - val_loss: 0.5902
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 129ms/step - accuracy: 0.6760 - loss: 0.6041 - val_accuracy: 0.6890 - val_loss: 0.5853
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - accuracy: 0.6970 - loss: 0.5791 - val_accuracy: 0.7050 - val_loss: 0.5766
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 139ms/step - accuracy: 0.7095 - loss: 0.5648 - val_accuracy: 0.7150 - val_loss: 0.5562
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 117ms/step - accuracy: 0.7220 - loss: 0.5497 - val_accuracy: 0.6710 - val_loss: 0.6397
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 123ms/step - accuracy: 0.7155 - loss: 0.5566 - val_accuracy: 0.7280 - val_loss: 0.5568
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - accuracy: 0.7530 - loss: 0.5109 - val_accuracy: 0.7320 - val_loss: 0.5371
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 124ms/step - accuracy: 0.7590 - loss: 0.5065 - val_accuracy: 0.7040 - val_loss: 0.5604
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - accuracy: 0.7565 - loss: 0.4998 - val_accuracy: 0.7290 - val_loss: 0.5356
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - accuracy: 0.7845 - loss: 0.4760 - val_accuracy: 0.7500 - val_loss: 0.5098
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - accuracy: 0.7795 - loss: 0.4670 - val_accuracy: 0.7430 - val_loss: 0.5237
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 123ms/step - accuracy: 0.8115 - loss: 0.4172 - val_accuracy: 0.7160 - val_loss: 0.6329
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - accuracy: 0.8235 - loss: 0.4244 - val_accuracy: 0.7370 - val_loss: 0.5291
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 138ms/step - accuracy: 0.8315 - loss: 0.3770 - val_accuracy: 0.7470 - val_loss: 0.6086
# Epoch 20/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - accuracy: 0.8285 - loss: 0.3919 - val_accuracy: 0.7770 - val_loss: 0.4741
# Epoch 21/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - accuracy: 0.8530 - loss: 0.3456 - val_accuracy: 0.7820 - val_loss: 0.4905
# Epoch 22/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.8765 - loss: 0.2969 - val_accuracy: 0.7800 - val_loss: 0.5669
# Epoch 23/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 132ms/step - accuracy: 0.8625 - loss: 0.3136 - val_accuracy: 0.7010 - val_loss: 0.7233
# Epoch 24/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 124ms/step - accuracy: 0.8850 - loss: 0.2770 - val_accuracy: 0.7890 - val_loss: 0.5581
# Epoch 25/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 123ms/step - accuracy: 0.9125 - loss: 0.2148 - val_accuracy: 0.8000 - val_loss: 0.4786
# Epoch 26/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - accuracy: 0.9330 - loss: 0.1797 - val_accuracy: 0.7800 - val_loss: 0.6581
# Epoch 27/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - accuracy: 0.9350 - loss: 0.1629 - val_accuracy: 0.8020 - val_loss: 0.5694
# Epoch 28/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 123ms/step - accuracy: 0.9310 - loss: 0.1733 - val_accuracy: 0.7760 - val_loss: 0.5697
# Epoch 29/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - accuracy: 0.9510 - loss: 0.1184 - val_accuracy: 0.8020 - val_loss: 0.5405
# Epoch 30/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - accuracy: 0.9600 - loss: 0.1028 - val_accuracy: 0.8200 - val_loss: 0.5965
# Epoch 31/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 124ms/step - accuracy: 0.9800 - loss: 0.0574 - val_accuracy: 0.8200 - val_loss: 0.6519
# Epoch 32/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9710 - loss: 0.0757 - val_accuracy: 0.8030 - val_loss: 0.6629
# Epoch 33/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 113ms/step - accuracy: 0.9630 - loss: 0.0917 - val_accuracy: 0.8050 - val_loss: 0.7236
# Epoch 34/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - accuracy: 0.9470 - loss: 0.1510 - val_accuracy: 0.7930 - val_loss: 0.6009
# Epoch 35/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 131ms/step - accuracy: 0.9820 - loss: 0.0575 - val_accuracy: 0.8150 - val_loss: 0.6513
# Epoch 36/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - accuracy: 0.9930 - loss: 0.0324 - val_accuracy: 0.8240 - val_loss: 0.6555
# Epoch 37/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - accuracy: 0.9955 - loss: 0.0171 - val_accuracy: 0.8180 - val_loss: 0.7427
# Epoch 38/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - accuracy: 0.9935 - loss: 0.0242 - val_accuracy: 0.8130 - val_loss: 0.7697
# Epoch 39/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - accuracy: 0.9915 - loss: 0.0315 - val_accuracy: 0.8190 - val_loss: 0.7453
# Epoch 40/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - accuracy: 0.9990 - loss: 0.0126 - val_accuracy: 0.8340 - val_loss: 0.7296
# Epoch 41/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.9990 - loss: 0.0053 - val_accuracy: 0.8380 - val_loss: 0.7821
# Epoch 42/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - accuracy: 0.9990 - loss: 0.0080 - val_accuracy: 0.8230 - val_loss: 0.7840
# Epoch 43/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 124ms/step - accuracy: 0.9995 - loss: 0.0044 - val_accuracy: 0.8400 - val_loss: 0.8650
# Epoch 44/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.8340 - val_loss: 0.8644
# Epoch 45/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 114ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.8430 - val_loss: 0.8866
# Epoch 46/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.8350 - val_loss: 0.9115
# Epoch 47/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - accuracy: 1.0000 - loss: 9.0500e-04 - val_accuracy: 0.8340 - val_loss: 0.9491
# Epoch 48/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 113ms/step - accuracy: 1.0000 - loss: 7.8259e-04 - val_accuracy: 0.8390 - val_loss: 0.9472
# Epoch 49/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - accuracy: 1.0000 - loss: 6.7271e-04 - val_accuracy: 0.8400 - val_loss: 0.9621
# Epoch 50/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 139ms/step - accuracy: 1.0000 - loss: 5.5740e-04 - val_accuracy: 0.8350 - val_loss: 0.9765

# %%
import matplotlib.pyplot as plt

accuracy = history.history["accuracy"]
val_accuracy = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(accuracy) + 1)

plt.plot(epochs, accuracy, "r--", label="Training accuracy")
plt.plot(epochs, val_accuracy, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()

plt.plot(epochs, loss, "r--", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %%
test_model = keras.models.load_model("convnet_from_scratch.keras")
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - accuracy: 0.7885 - loss: 0.4645
# Test accuracy: 0.789

# %% [markdown]
# #### Using data augmentation

# %%
data_augmentation_layers = [
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.2),
]

def data_augmentation(images, targets):
    for layer in data_augmentation_layers:
        images = layer(images)
    return images, targets

augmented_train_dataset = train_dataset.map(
    data_augmentation, num_parallel_calls=8
)
augmented_train_dataset = augmented_train_dataset.prefetch(tf.data.AUTOTUNE)

# %%
plt.figure(figsize=(10, 10))
for image_batch, _ in train_dataset.take(1):
    image = image_batch[0]
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        augmented_image, _ = data_augmentation(image, None)
        augmented_image = keras.ops.convert_to_numpy(augmented_image)
        plt.imshow(augmented_image.astype("uint8"))
        plt.axis("off")

# %%
inputs = keras.Input(shape=(180, 180, 3))
x = layers.Rescaling(1.0 / 255)(inputs)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=512, kernel_size=3, activation="relu")(x)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.25)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.compile(
    loss="binary_crossentropy",
    optimizer="adam",
    metrics=["accuracy"],
)

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch_with_augmentation.keras",
        save_best_only=True,
        monitor="val_loss",
    )
]
history = model.fit(
    augmented_train_dataset,
    epochs=100,
    validation_data=validation_dataset,
    callbacks=callbacks,
)
# Out:
# Epoch 1/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 19s 398ms/step - accuracy: 0.5095 - loss: 0.6956 - val_accuracy: 0.5000 - val_loss: 0.6894
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 411ms/step - accuracy: 0.5725 - loss: 0.6819 - val_accuracy: 0.6040 - val_loss: 0.6635
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 386ms/step - accuracy: 0.5500 - loss: 0.6873 - val_accuracy: 0.6310 - val_loss: 0.6520
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 413ms/step - accuracy: 0.6295 - loss: 0.6540 - val_accuracy: 0.6240 - val_loss: 0.6387
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 411ms/step - accuracy: 0.6115 - loss: 0.6534 - val_accuracy: 0.6490 - val_loss: 0.6296
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 404ms/step - accuracy: 0.6335 - loss: 0.6461 - val_accuracy: 0.6550 - val_loss: 0.6198
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 406ms/step - accuracy: 0.6515 - loss: 0.6261 - val_accuracy: 0.6530 - val_loss: 0.6170
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 401ms/step - accuracy: 0.6180 - loss: 0.6672 - val_accuracy: 0.6700 - val_loss: 0.6179
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 405ms/step - accuracy: 0.6420 - loss: 0.6283 - val_accuracy: 0.6780 - val_loss: 0.5977
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 418ms/step - accuracy: 0.6795 - loss: 0.6124 - val_accuracy: 0.6470 - val_loss: 0.6282
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 425ms/step - accuracy: 0.6650 - loss: 0.6158 - val_accuracy: 0.6860 - val_loss: 0.5887
# Epoch 12/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 408ms/step - accuracy: 0.6845 - loss: 0.5996 - val_accuracy: 0.6770 - val_loss: 0.5980
# Epoch 13/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 413ms/step - accuracy: 0.6855 - loss: 0.5954 - val_accuracy: 0.6950 - val_loss: 0.5902
# Epoch 14/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 391ms/step - accuracy: 0.6975 - loss: 0.5841 - val_accuracy: 0.6990 - val_loss: 0.5854
# Epoch 15/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 436ms/step - accuracy: 0.6840 - loss: 0.5923 - val_accuracy: 0.6970 - val_loss: 0.5784
# Epoch 16/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 19s 401ms/step - accuracy: 0.6730 - loss: 0.6002 - val_accuracy: 0.7020 - val_loss: 0.5713
# Epoch 17/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 405ms/step - accuracy: 0.6985 - loss: 0.5669 - val_accuracy: 0.6920 - val_loss: 0.5806
# Epoch 18/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 414ms/step - accuracy: 0.7030 - loss: 0.5666 - val_accuracy: 0.7150 - val_loss: 0.5648
# Epoch 19/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 418ms/step - accuracy: 0.7050 - loss: 0.5719 - val_accuracy: 0.6920 - val_loss: 0.5779
# Epoch 20/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 402ms/step - accuracy: 0.7255 - loss: 0.5562 - val_accuracy: 0.7180 - val_loss: 0.5606
# Epoch 21/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 386ms/step - accuracy: 0.7245 - loss: 0.5553 - val_accuracy: 0.7160 - val_loss: 0.5678
# Epoch 22/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 422ms/step - accuracy: 0.7160 - loss: 0.5656 - val_accuracy: 0.6970 - val_loss: 0.5991
# Epoch 23/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 410ms/step - accuracy: 0.7355 - loss: 0.5407 - val_accuracy: 0.7260 - val_loss: 0.5498
# Epoch 24/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 422ms/step - accuracy: 0.7160 - loss: 0.5691 - val_accuracy: 0.6890 - val_loss: 0.6047
# Epoch 25/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 398ms/step - accuracy: 0.6870 - loss: 0.5911 - val_accuracy: 0.7230 - val_loss: 0.5511
# Epoch 26/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 403ms/step - accuracy: 0.7350 - loss: 0.5404 - val_accuracy: 0.7410 - val_loss: 0.5396
# Epoch 27/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 429ms/step - accuracy: 0.7410 - loss: 0.5303 - val_accuracy: 0.7360 - val_loss: 0.5407
# Epoch 28/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 447ms/step - accuracy: 0.7490 - loss: 0.5151 - val_accuracy: 0.7100 - val_loss: 0.5738
# Epoch 29/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 426ms/step - accuracy: 0.7300 - loss: 0.5356 - val_accuracy: 0.7390 - val_loss: 0.5261
# Epoch 30/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 416ms/step - accuracy: 0.7485 - loss: 0.5226 - val_accuracy: 0.7040 - val_loss: 0.5672
# Epoch 31/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 424ms/step - accuracy: 0.7660 - loss: 0.5050 - val_accuracy: 0.7660 - val_loss: 0.5162
# Epoch 32/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 391ms/step - accuracy: 0.7240 - loss: 0.5471 - val_accuracy: 0.7290 - val_loss: 0.5440
# Epoch 33/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 419ms/step - accuracy: 0.7410 - loss: 0.5356 - val_accuracy: 0.6600 - val_loss: 0.6249
# Epoch 34/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 393ms/step - accuracy: 0.7510 - loss: 0.5191 - val_accuracy: 0.7620 - val_loss: 0.5013
# Epoch 35/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 401ms/step - accuracy: 0.7680 - loss: 0.4934 - val_accuracy: 0.7090 - val_loss: 0.5717
# Epoch 36/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 391ms/step - accuracy: 0.7505 - loss: 0.4983 - val_accuracy: 0.7820 - val_loss: 0.4730
# Epoch 37/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 411ms/step - accuracy: 0.7660 - loss: 0.4868 - val_accuracy: 0.7610 - val_loss: 0.4914
# Epoch 38/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 423ms/step - accuracy: 0.7810 - loss: 0.4661 - val_accuracy: 0.7780 - val_loss: 0.4887
# Epoch 39/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 422ms/step - accuracy: 0.7830 - loss: 0.4686 - val_accuracy: 0.7870 - val_loss: 0.4618
# Epoch 40/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 405ms/step - accuracy: 0.7940 - loss: 0.4462 - val_accuracy: 0.7750 - val_loss: 0.4657
# Epoch 41/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 418ms/step - accuracy: 0.8065 - loss: 0.4329 - val_accuracy: 0.7700 - val_loss: 0.4873
# Epoch 42/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 411ms/step - accuracy: 0.7920 - loss: 0.4620 - val_accuracy: 0.7800 - val_loss: 0.4555
# Epoch 43/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 404ms/step - accuracy: 0.8035 - loss: 0.4328 - val_accuracy: 0.7400 - val_loss: 0.5304
# Epoch 44/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 415ms/step - accuracy: 0.7920 - loss: 0.4485 - val_accuracy: 0.7670 - val_loss: 0.4937
# Epoch 45/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 421ms/step - accuracy: 0.8000 - loss: 0.4344 - val_accuracy: 0.7920 - val_loss: 0.4432
# Epoch 46/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 427ms/step - accuracy: 0.8200 - loss: 0.4047 - val_accuracy: 0.7910 - val_loss: 0.4573
# Epoch 47/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 405ms/step - accuracy: 0.8145 - loss: 0.4221 - val_accuracy: 0.7770 - val_loss: 0.4825
# Epoch 48/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 408ms/step - accuracy: 0.8195 - loss: 0.4067 - val_accuracy: 0.7850 - val_loss: 0.4445
# Epoch 49/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 395ms/step - accuracy: 0.8240 - loss: 0.3812 - val_accuracy: 0.7730 - val_loss: 0.4838
# Epoch 50/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 407ms/step - accuracy: 0.8235 - loss: 0.3847 - val_accuracy: 0.7970 - val_loss: 0.4344
# Epoch 51/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 399ms/step - accuracy: 0.8255 - loss: 0.3918 - val_accuracy: 0.8070 - val_loss: 0.4432
# Epoch 52/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 407ms/step - accuracy: 0.8185 - loss: 0.3898 - val_accuracy: 0.8120 - val_loss: 0.4135
# Epoch 53/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 408ms/step - accuracy: 0.8385 - loss: 0.3652 - val_accuracy: 0.8080 - val_loss: 0.4223
# Epoch 54/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 417ms/step - accuracy: 0.8390 - loss: 0.3593 - val_accuracy: 0.8090 - val_loss: 0.4255
# Epoch 55/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 418ms/step - accuracy: 0.8535 - loss: 0.3521 - val_accuracy: 0.8160 - val_loss: 0.4346
# Epoch 56/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 392ms/step - accuracy: 0.8485 - loss: 0.3651 - val_accuracy: 0.8030 - val_loss: 0.4438
# Epoch 57/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 415ms/step - accuracy: 0.8565 - loss: 0.3500 - val_accuracy: 0.8120 - val_loss: 0.4385
# Epoch 58/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 411ms/step - accuracy: 0.8390 - loss: 0.3652 - val_accuracy: 0.8100 - val_loss: 0.4309
# Epoch 59/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 409ms/step - accuracy: 0.8605 - loss: 0.3164 - val_accuracy: 0.8030 - val_loss: 0.4628
# Epoch 60/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 416ms/step - accuracy: 0.8510 - loss: 0.3364 - val_accuracy: 0.8150 - val_loss: 0.4261
# Epoch 61/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 412ms/step - accuracy: 0.8580 - loss: 0.3160 - val_accuracy: 0.8100 - val_loss: 0.4586
# Epoch 62/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 411ms/step - accuracy: 0.8540 - loss: 0.3301 - val_accuracy: 0.8310 - val_loss: 0.3948
# Epoch 63/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 404ms/step - accuracy: 0.8690 - loss: 0.3022 - val_accuracy: 0.8120 - val_loss: 0.4453
# Epoch 64/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 422ms/step - accuracy: 0.8630 - loss: 0.3091 - val_accuracy: 0.8290 - val_loss: 0.4318
# Epoch 65/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 408ms/step - accuracy: 0.8725 - loss: 0.3039 - val_accuracy: 0.8380 - val_loss: 0.3974
# Epoch 66/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 412ms/step - accuracy: 0.8635 - loss: 0.3081 - val_accuracy: 0.8200 - val_loss: 0.4247
# Epoch 67/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 423ms/step - accuracy: 0.8700 - loss: 0.2959 - val_accuracy: 0.8290 - val_loss: 0.3824
# Epoch 68/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 414ms/step - accuracy: 0.8765 - loss: 0.2916 - val_accuracy: 0.8300 - val_loss: 0.3938
# Epoch 69/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 417ms/step - accuracy: 0.8615 - loss: 0.3246 - val_accuracy: 0.8230 - val_loss: 0.3943
# Epoch 70/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 411ms/step - accuracy: 0.8785 - loss: 0.2880 - val_accuracy: 0.8560 - val_loss: 0.3745
# Epoch 71/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 406ms/step - accuracy: 0.8880 - loss: 0.2537 - val_accuracy: 0.8450 - val_loss: 0.3863
# Epoch 72/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 406ms/step - accuracy: 0.8905 - loss: 0.2588 - val_accuracy: 0.8420 - val_loss: 0.4187
# Epoch 73/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 403ms/step - accuracy: 0.8820 - loss: 0.2795 - val_accuracy: 0.8220 - val_loss: 0.4277
# Epoch 74/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 411ms/step - accuracy: 0.8960 - loss: 0.2377 - val_accuracy: 0.8070 - val_loss: 0.5678
# Epoch 75/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 409ms/step - accuracy: 0.8805 - loss: 0.2806 - val_accuracy: 0.8100 - val_loss: 0.5497
# Epoch 76/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 405ms/step - accuracy: 0.8680 - loss: 0.3058 - val_accuracy: 0.8330 - val_loss: 0.4188
# Epoch 77/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 413ms/step - accuracy: 0.9025 - loss: 0.2285 - val_accuracy: 0.8530 - val_loss: 0.4015
# Epoch 78/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 411ms/step - accuracy: 0.9035 - loss: 0.2320 - val_accuracy: 0.8290 - val_loss: 0.4150
# Epoch 79/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 418ms/step - accuracy: 0.9055 - loss: 0.2333 - val_accuracy: 0.8510 - val_loss: 0.4095
# Epoch 80/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 405ms/step - accuracy: 0.9080 - loss: 0.2191 - val_accuracy: 0.8260 - val_loss: 0.4435
# Epoch 81/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 413ms/step - accuracy: 0.9060 - loss: 0.2363 - val_accuracy: 0.8350 - val_loss: 0.4240
# Epoch 82/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 408ms/step - accuracy: 0.8960 - loss: 0.2508 - val_accuracy: 0.8440 - val_loss: 0.4377
# Epoch 83/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 403ms/step - accuracy: 0.9155 - loss: 0.2021 - val_accuracy: 0.8310 - val_loss: 0.4385
# Epoch 84/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 406ms/step - accuracy: 0.8920 - loss: 0.2463 - val_accuracy: 0.8560 - val_loss: 0.3866
# Epoch 85/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 417ms/step - accuracy: 0.9095 - loss: 0.2202 - val_accuracy: 0.7970 - val_loss: 0.6405
# Epoch 86/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 416ms/step - accuracy: 0.9160 - loss: 0.2142 - val_accuracy: 0.8580 - val_loss: 0.4169
# Epoch 87/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 405ms/step - accuracy: 0.8985 - loss: 0.2355 - val_accuracy: 0.8380 - val_loss: 0.4093
# Epoch 88/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 421ms/step - accuracy: 0.9185 - loss: 0.1900 - val_accuracy: 0.8410 - val_loss: 0.4417
# Epoch 89/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 423ms/step - accuracy: 0.9240 - loss: 0.1954 - val_accuracy: 0.8620 - val_loss: 0.3842
# Epoch 90/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 401ms/step - accuracy: 0.9090 - loss: 0.2019 - val_accuracy: 0.8400 - val_loss: 0.4014
# Epoch 91/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 418ms/step - accuracy: 0.9290 - loss: 0.1752 - val_accuracy: 0.8460 - val_loss: 0.4610
# Epoch 92/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 407ms/step - accuracy: 0.9215 - loss: 0.1857 - val_accuracy: 0.8380 - val_loss: 0.4776
# Epoch 93/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 407ms/step - accuracy: 0.9280 - loss: 0.1769 - val_accuracy: 0.8200 - val_loss: 0.6525
# Epoch 94/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 415ms/step - accuracy: 0.9280 - loss: 0.1884 - val_accuracy: 0.8610 - val_loss: 0.4298
# Epoch 95/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 409ms/step - accuracy: 0.9345 - loss: 0.1705 - val_accuracy: 0.8600 - val_loss: 0.4251
# Epoch 96/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 409ms/step - accuracy: 0.9335 - loss: 0.1614 - val_accuracy: 0.8570 - val_loss: 0.4603
# Epoch 97/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 414ms/step - accuracy: 0.9315 - loss: 0.1549 - val_accuracy: 0.8310 - val_loss: 0.6066
# Epoch 98/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 407ms/step - accuracy: 0.9275 - loss: 0.1745 - val_accuracy: 0.8360 - val_loss: 0.5425
# Epoch 99/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 421ms/step - accuracy: 0.9350 - loss: 0.1628 - val_accuracy: 0.8340 - val_loss: 0.4519
# Epoch 100/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 405ms/step - accuracy: 0.9265 - loss: 0.1771 - val_accuracy: 0.8460 - val_loss: 0.5423

# %%
test_model = keras.models.load_model(
    "convnet_from_scratch_with_augmentation.keras"
)
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8340 - loss: 0.4122
# Test accuracy: 0.834

# %% [markdown]
# ### Using a pretrained model

# %% [markdown]
# #### Feature extraction with a pretrained model

# %%
import keras_hub

conv_base = keras_hub.models.Backbone.from_preset("xception_41_imagenet")
# Out:
# Downloading from https://www.kaggle.com/api/v1/models/keras/xception/keras/xception_41_imagenet/2/download/config.json...
# 100%|██████████| 1.79k/1.79k [00:00<00:00, 2.93MB/s]
# Downloading from https://www.kaggle.com/api/v1/models/keras/xception/keras/xception_41_imagenet/2/download/model.weights.h5...
# 100%|██████████| 79.9M/79.9M [00:02<00:00, 39.4MB/s]

# %%
preprocessor = keras_hub.layers.ImageConverter.from_preset(
    "xception_41_imagenet",
    image_size=(180, 180),
)
# Out:
# Downloading from https://www.kaggle.com/api/v1/models/keras/xception/keras/xception_41_imagenet/2/download/image_converter.json...
# 100%|██████████| 762/762 [00:00<00:00, 966kB/s]

# %% [markdown]
# ##### Fast feature extraction without data augmentation

# %%
def get_features_and_labels(dataset):
    all_features = []
    all_labels = []
    for images, labels in dataset:
        preprocessed_images = preprocessor(images)
        features = conv_base.predict(preprocessed_images, verbose=0)
        all_features.append(features)
        all_labels.append(labels)
    return np.concatenate(all_features), np.concatenate(all_labels)

train_features, train_labels = get_features_and_labels(train_dataset)
val_features, val_labels = get_features_and_labels(validation_dataset)
test_features, test_labels = get_features_and_labels(test_dataset)

# %%
train_features.shape
# Out:
# (2000, 6, 6, 2048)

# %%
inputs = keras.Input(shape=(6, 6, 2048))
x = layers.GlobalAveragePooling2D()(inputs)
x = layers.Dense(256, activation="relu")(x)
x = layers.Dropout(0.25)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)
model.compile(
    loss="binary_crossentropy",
    optimizer="adam",
    metrics=["accuracy"],
)

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="feature_extraction.keras",
        save_best_only=True,
        monitor="val_loss",
    )
]
history = model.fit(
    train_features,
    train_labels,
    epochs=10,
    validation_data=(val_features, val_labels),
    callbacks=callbacks,
)
# Out:
# Epoch 1/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9695 - loss: 0.0876 - val_accuracy: 0.9830 - val_loss: 0.0465
# Epoch 2/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9910 - loss: 0.0283 - val_accuracy: 0.9800 - val_loss: 0.0536
# Epoch 3/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9920 - loss: 0.0245 - val_accuracy: 0.9860 - val_loss: 0.0441
# Epoch 4/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9930 - loss: 0.0135 - val_accuracy: 0.9850 - val_loss: 0.0619
# Epoch 5/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9965 - loss: 0.0079 - val_accuracy: 0.9830 - val_loss: 0.0636
# Epoch 6/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9980 - loss: 0.0043 - val_accuracy: 0.9840 - val_loss: 0.0575
# Epoch 7/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.9820 - val_loss: 0.0760
# Epoch 8/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.9830 - val_loss: 0.0715
# Epoch 9/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 5.9167e-04 - val_accuracy: 0.9830 - val_loss: 0.0699
# Epoch 10/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 3.3332e-04 - val_accuracy: 0.9840 - val_loss: 0.0673

# %%
import matplotlib.pyplot as plt

acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, "r--", label="Training accuracy")
plt.plot(epochs, val_acc, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "r--", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %%
test_model = keras.models.load_model("feature_extraction.keras")
test_loss, test_acc = test_model.evaluate(test_features, test_labels)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9830 - loss: 0.0589
# Test accuracy: 0.983

# %% [markdown]
# ##### Feature extraction together with data augmentation

# %%
import keras_hub

conv_base = keras_hub.models.Backbone.from_preset(
    "xception_41_imagenet",
    trainable=False,
)

# %%
conv_base.trainable = True
len(conv_base.trainable_weights)
# Out:
# 154

# %%
conv_base.trainable = False
len(conv_base.trainable_weights)
# Out:
# 0

# %%
inputs = keras.Input(shape=(180, 180, 3))
x = preprocessor(inputs)
x = conv_base(x)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.25)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)
model.compile(
    loss="binary_crossentropy",
    optimizer="adam",
    metrics=["accuracy"],
)

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="feature_extraction_with_data_augmentation.keras",
        save_best_only=True,
        monitor="val_loss",
    )
]
history = model.fit(
    augmented_train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    callbacks=callbacks,
)
# Out:
# Epoch 1/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - accuracy: 0.9245 - loss: 0.1971 - val_accuracy: 0.9850 - val_loss: 0.0621
# Epoch 2/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 476ms/step - accuracy: 0.9755 - loss: 0.0797 - val_accuracy: 0.9840 - val_loss: 0.0558
# Epoch 3/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 447ms/step - accuracy: 0.9675 - loss: 0.1203 - val_accuracy: 0.9820 - val_loss: 0.0620
# Epoch 4/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 440ms/step - accuracy: 0.9765 - loss: 0.0724 - val_accuracy: 0.9870 - val_loss: 0.0484
# Epoch 5/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 468ms/step - accuracy: 0.9675 - loss: 0.0864 - val_accuracy: 0.9840 - val_loss: 0.0623
# Epoch 6/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 458ms/step - accuracy: 0.9735 - loss: 0.0747 - val_accuracy: 0.9860 - val_loss: 0.0501
# Epoch 7/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 447ms/step - accuracy: 0.9780 - loss: 0.0611 - val_accuracy: 0.9830 - val_loss: 0.0501
# Epoch 8/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 455ms/step - accuracy: 0.9805 - loss: 0.0625 - val_accuracy: 0.9760 - val_loss: 0.0882
# Epoch 9/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 466ms/step - accuracy: 0.9785 - loss: 0.0651 - val_accuracy: 0.9820 - val_loss: 0.0651
# Epoch 10/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 424ms/step - accuracy: 0.9795 - loss: 0.0524 - val_accuracy: 0.9800 - val_loss: 0.0598
# Epoch 11/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 461ms/step - accuracy: 0.9790 - loss: 0.0520 - val_accuracy: 0.9820 - val_loss: 0.0565
# Epoch 12/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 462ms/step - accuracy: 0.9835 - loss: 0.0529 - val_accuracy: 0.9830 - val_loss: 0.0586
# Epoch 13/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 455ms/step - accuracy: 0.9805 - loss: 0.0600 - val_accuracy: 0.9830 - val_loss: 0.0643
# Epoch 14/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 463ms/step - accuracy: 0.9790 - loss: 0.0576 - val_accuracy: 0.9810 - val_loss: 0.0656
# Epoch 15/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 415ms/step - accuracy: 0.9855 - loss: 0.0378 - val_accuracy: 0.9800 - val_loss: 0.0586
# Epoch 16/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 459ms/step - accuracy: 0.9835 - loss: 0.0491 - val_accuracy: 0.9820 - val_loss: 0.0565
# Epoch 17/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 467ms/step - accuracy: 0.9845 - loss: 0.0446 - val_accuracy: 0.9810 - val_loss: 0.0543
# Epoch 18/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 450ms/step - accuracy: 0.9845 - loss: 0.0409 - val_accuracy: 0.9820 - val_loss: 0.0536
# Epoch 19/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 466ms/step - accuracy: 0.9785 - loss: 0.0528 - val_accuracy: 0.9810 - val_loss: 0.0679
# Epoch 20/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 458ms/step - accuracy: 0.9875 - loss: 0.0385 - val_accuracy: 0.9810 - val_loss: 0.0538
# Epoch 21/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 19s 406ms/step - accuracy: 0.9850 - loss: 0.0397 - val_accuracy: 0.9830 - val_loss: 0.0535
# Epoch 22/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 455ms/step - accuracy: 0.9820 - loss: 0.0536 - val_accuracy: 0.9790 - val_loss: 0.0593
# Epoch 23/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 461ms/step - accuracy: 0.9800 - loss: 0.0553 - val_accuracy: 0.9760 - val_loss: 0.0607
# Epoch 24/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 461ms/step - accuracy: 0.9915 - loss: 0.0247 - val_accuracy: 0.9820 - val_loss: 0.0639
# Epoch 25/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 429ms/step - accuracy: 0.9815 - loss: 0.0501 - val_accuracy: 0.9840 - val_loss: 0.0542
# Epoch 26/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 426ms/step - accuracy: 0.9865 - loss: 0.0379 - val_accuracy: 0.9850 - val_loss: 0.0506
# Epoch 27/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 458ms/step - accuracy: 0.9855 - loss: 0.0289 - val_accuracy: 0.9790 - val_loss: 0.0691
# Epoch 28/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 457ms/step - accuracy: 0.9660 - loss: 0.0979 - val_accuracy: 0.9820 - val_loss: 0.0565
# Epoch 29/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 450ms/step - accuracy: 0.9780 - loss: 0.0544 - val_accuracy: 0.9840 - val_loss: 0.0580
# Epoch 30/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 463ms/step - accuracy: 0.9885 - loss: 0.0323 - val_accuracy: 0.9830 - val_loss: 0.0525

# %%
test_model = keras.models.load_model(
    "feature_extraction_with_data_augmentation.keras"
)
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 318 variables whereas the saved optimizer has 10 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 227ms/step - accuracy: 0.9835 - loss: 0.0571
# Test accuracy: 0.984

# %% [markdown]
# #### Fine-tuning a pretrained model

# %%
model.compile(
    loss="binary_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=1e-5),
    metrics=["accuracy"],
)

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="fine_tuning.keras",
        save_best_only=True,
        monitor="val_loss",
    )
]
history = model.fit(
    augmented_train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    callbacks=callbacks,
)
# Out:
# Epoch 1/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 29s 706ms/step - accuracy: 0.9915 - loss: 0.0241 - val_accuracy: 0.9830 - val_loss: 0.0524
# Epoch 2/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 483ms/step - accuracy: 0.9885 - loss: 0.0274 - val_accuracy: 0.9820 - val_loss: 0.0522
# Epoch 3/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 471ms/step - accuracy: 0.9940 - loss: 0.0199 - val_accuracy: 0.9820 - val_loss: 0.0521
# Epoch 4/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 442ms/step - accuracy: 0.9895 - loss: 0.0338 - val_accuracy: 0.9830 - val_loss: 0.0520
# Epoch 5/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 448ms/step - accuracy: 0.9910 - loss: 0.0270 - val_accuracy: 0.9830 - val_loss: 0.0520
# Epoch 6/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 475ms/step - accuracy: 0.9865 - loss: 0.0376 - val_accuracy: 0.9830 - val_loss: 0.0518
# Epoch 7/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 482ms/step - accuracy: 0.9890 - loss: 0.0310 - val_accuracy: 0.9830 - val_loss: 0.0517
# Epoch 8/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 428ms/step - accuracy: 0.9910 - loss: 0.0281 - val_accuracy: 0.9830 - val_loss: 0.0517
# Epoch 9/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 457ms/step - accuracy: 0.9910 - loss: 0.0210 - val_accuracy: 0.9820 - val_loss: 0.0518
# Epoch 10/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 453ms/step - accuracy: 0.9895 - loss: 0.0248 - val_accuracy: 0.9830 - val_loss: 0.0519
# Epoch 11/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 452ms/step - accuracy: 0.9900 - loss: 0.0282 - val_accuracy: 0.9830 - val_loss: 0.0520
# Epoch 12/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 456ms/step - accuracy: 0.9895 - loss: 0.0281 - val_accuracy: 0.9830 - val_loss: 0.0518
# Epoch 13/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 460ms/step - accuracy: 0.9915 - loss: 0.0268 - val_accuracy: 0.9830 - val_loss: 0.0519
# Epoch 14/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 437ms/step - accuracy: 0.9925 - loss: 0.0267 - val_accuracy: 0.9820 - val_loss: 0.0519
# Epoch 15/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 472ms/step - accuracy: 0.9865 - loss: 0.0343 - val_accuracy: 0.9830 - val_loss: 0.0516
# Epoch 16/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 480ms/step - accuracy: 0.9930 - loss: 0.0195 - val_accuracy: 0.9830 - val_loss: 0.0514
# Epoch 17/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 16s 488ms/step - accuracy: 0.9915 - loss: 0.0198 - val_accuracy: 0.9830 - val_loss: 0.0514
# Epoch 18/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 478ms/step - accuracy: 0.9895 - loss: 0.0309 - val_accuracy: 0.9830 - val_loss: 0.0513
# Epoch 19/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 453ms/step - accuracy: 0.9915 - loss: 0.0226 - val_accuracy: 0.9830 - val_loss: 0.0512
# Epoch 20/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 436ms/step - accuracy: 0.9900 - loss: 0.0266 - val_accuracy: 0.9840 - val_loss: 0.0513
# Epoch 21/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 444ms/step - accuracy: 0.9885 - loss: 0.0302 - val_accuracy: 0.9840 - val_loss: 0.0514
# Epoch 22/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 454ms/step - accuracy: 0.9905 - loss: 0.0270 - val_accuracy: 0.9830 - val_loss: 0.0512
# Epoch 23/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 467ms/step - accuracy: 0.9905 - loss: 0.0307 - val_accuracy: 0.9830 - val_loss: 0.0514
# Epoch 24/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 421ms/step - accuracy: 0.9855 - loss: 0.0341 - val_accuracy: 0.9840 - val_loss: 0.0516
# Epoch 25/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 461ms/step - accuracy: 0.9920 - loss: 0.0313 - val_accuracy: 0.9830 - val_loss: 0.0514
# Epoch 26/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 468ms/step - accuracy: 0.9900 - loss: 0.0265 - val_accuracy: 0.9830 - val_loss: 0.0513
# Epoch 27/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 458ms/step - accuracy: 0.9880 - loss: 0.0304 - val_accuracy: 0.9830 - val_loss: 0.0513
# Epoch 28/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 21s 461ms/step - accuracy: 0.9900 - loss: 0.0246 - val_accuracy: 0.9830 - val_loss: 0.0513
# Epoch 29/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 467ms/step - accuracy: 0.9925 - loss: 0.0211 - val_accuracy: 0.9830 - val_loss: 0.0514
# Epoch 30/30
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 469ms/step - accuracy: 0.9900 - loss: 0.0315 - val_accuracy: 0.9840 - val_loss: 0.0514

# %%
model = keras.models.load_model("fine_tuning.keras")
test_loss, test_acc = model.evaluate(test_dataset)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 235ms/step - accuracy: 0.9870 - loss: 0.0535
# Test accuracy: 0.987
